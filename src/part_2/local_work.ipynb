# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows", 50)  # Set to any number you prefer

# %% [markdown]
# # Functions

# %% [markdown]
# # Data

# %%
df = pd.read_csv("../../data/part_2/framingham.csv")

# %%
display(df)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
df.isnull().sum().sum()
# Out:
# 645

# %%
df.shape
# Out:
# (4240, 16)

# %%
max_possible_null_percentage = (df.isnull().sum().sum()) / (df.shape[0])
print(max_possible_null_percentage)
# Out:
# 0.15212264150943397

# %%
var = df.copy()

var.dropna(inplace = True)

blanket_null_dropped_df_pct = (var.shape[0]) / (df.shape[0])

# %%
blanket_null_dropped_df_pct
# Out:
# 0.8627358490566037

# %%
var.shape
# Out:
# (3658, 16)

# %% [markdown]
# It's honeslty not possible to understand what these actual values of missing data is. We can use some algorithms to infer what they are based on common patterns across the rest of the data, but with the importance of classifying heart disease, making up data could be a costly mistake of misdiagnosing true heart disease. We don't want to sway our model with incorrect data. This would also get us in trouble.

# %%
display(
    df[
        (df["education"].isnull()) |
        (df["cigsPerDay"].isnull()) |
        (df["BPMeds"].isnull()) |
        (df["totChol"].isnull()) |
        (df["BMI"].isnull()) |
        
    ]
)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 33       1   61        NaN              1         5.0     0.0
# 36       1   56        NaN              0         0.0     0.0
# 72       0   37        NaN              0         0.0     0.0
# 131      1   43        4.0              1         NaN     0.0
# 139      1   49        4.0              1         NaN     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4082     1   47        NaN              0         0.0     0.0
# 4098     1   37        NaN              1        20.0     0.0
# 4121     0   55        NaN              0         0.0     0.0
# 4122     1   69        NaN              1        23.0     0.0
# 4138     1   67        NaN              1        25.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 33                  0             0         0    175.0  134.0   82.5  18.59
# ...

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object
